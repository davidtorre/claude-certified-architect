# %% [markdown]
# Learn how to use Claude Code, an AI coding assistant that lives in your terminal. It reads files, writes code, runs commands, and executes multi-step tasks autonomously. This module covers installation, the core tools, effective workflows, and hands-on practice with a CLI simulator.
# 1. Getting Started with Claude Code
# 2. The Agentic Loop -- How Claude Code Thinks: Observe, Think, Act, Observe results, repeat or respond
# 3. The Core Tools Arsenal: Read, Write, Edit, Bash, Glob, Grep, Agent,
# WebSearch / WebFetch
# 4. Codebase Exploration Patterns
# 5. Making Changes and Verifying
# 6. Context Window Management
# 7. CLAUDE.md -- Your Project's AI Config File

# %%
# Install Claude Code globally
npm install -g @anthropic-ai/claude-code

# Verify installation
claude --version

# Start Claude Code in your project
cd ~/my-project
claude

# Or run a one-shot command
claude "What does this project do?"

# %%
# claude.md example
# Project: Task Management API

## Tech Stack
- Backend: TypeScript + Express.js
- Database: PostgreSQL with Prisma ORM
- Testing: Vitest with fixtures
- Deployment: Docker + Kubernetes

## Commands
- Run tests: `npm test`
- Start dev server: `npm run dev`
- Build: `npm run build`
- Lint: `npm run lint`

## Coding Rules
- ALWAYS use TypeScript strict mode
- NEVER use `any` types -- use `unknown` and type guards
- Prefer functional components with hooks
- All API routes must have input validation with Zod
- Use `const` over `let` wherever possible

## Important Directories
- src/routes/ -- API endpoint handlers
- src/services/ -- Business logic
- src/models/ -- Prisma models and types
- src/middleware/ -- Auth, validation, error handling
- tests/ -- Test files mirror src/ structure

## Context
- src/legacy/ is being deprecated. Do not add new code there.
- Use `node` (not `bun`) for all commands.
